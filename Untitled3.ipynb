# %% [markdown]
# <a href="https://colab.research.google.com/github/gichhollow/ty.works/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('housing.csv')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x=data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
#create are test data i.e for like 20% of the actual data 
#it for later use after the training and hyper parameters tunning of the data before launching to evaluate the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
train_data=x_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7302     -118.19     33.99                40.0       1547.0           434.0
# 22       -122.27     37.84                52.0       2436.0           541.0
# 17386    -120.44     34.97                22.0       1619.0           360.0
# 3397     -118.31     34.26                41.0       1297.0           327.0
# 564      -122.24     37.75                27.0       4051.0           753.0
# ...          ...       ...                 ...          ...             ...
# 33       -122.27     37.83                49.0       1655.0           366.0
# 15297    -117.35     33.16                22.0       1331.0           305.0
# 18021    -121.96     37.24                26.0       3032.0           605.0
# 15711    -122.44     37.79                52.0       2083.0           491.0
# 11196    -117.93     33.84                34.0       2160.0           298.0
#
#        population  households  median_income ocean_proximity  \
# 7302       1930.0       427.0         3.3869       <1H OCEAN
# 22         1015.0       478.0         1.7250        NEAR BAY
# 17386      1509.0       384.0         1.7941       <1H OCEAN
# 3397        733.0       315.0         3.0583       <1H OCEAN
# 564        1499.0       797.0         4.8711        NEAR BAY
# ...           ...         ...            ...             ...
# 33          754.0       329.0         1.3750        NEAR BAY
# 15297       580.0       193.0         3.9750      NEAR OCEAN
# 18021      1208.0       562.0         5.4683       <1H OCEAN
# 15711      1224.0       483.0         4.0882        NEAR BAY
# 11196       852.0       305.0         6.0531       <1H OCEAN
#
#        median_house_value
# 7302             157300.0
# 22               113900.0
# 17386            110300.0
# 3397             160300.0
# 564              286600.0
# ...                   ...
# 33               104900.0
# 15297            500001.0
# 18021            430900.0
# 15711            468800.0
# 11196            287100.0
#
# [16346 rows x 10 columns]

# %%
sns.pairplot(train_data)

# %%
#get multiple histograms showing the distribution of various features and their correlation to the target variable
train_data.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#to visualize a  correlation matrix we use a heatmap
#A correlation matrix is simply a table which displays the correlation coefficients for different variables. The matrix depicts the correlation between all the possible pairs of values in a table.
train_data.corr()
# Out:
# <ipython-input-16-138c70d9cf4c>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_data.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924695           -0.106153     0.047947
# latitude            -0.924695  1.000000            0.009540    -0.038632
# housing_median_age  -0.106153  0.009540            1.000000    -0.364775
# total_rooms          0.047947 -0.038632           -0.364775     1.000000
# total_bedrooms       0.072743 -0.069472           -0.324193     0.930874
# population           0.102751 -0.110369           -0.298712     0.854081
# households           0.059467 -0.073631           -0.306227     0.919410
# median_income       -0.014830 -0.080428           -0.124439     0.204539
# median_house_value  -0.045866 -0.144787            0.099531     0.139026
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.072743    0.102751    0.059467      -0.014830
# latitude                 -0.069472   -0.110369   -0.073631      -0.080428
# housing_median_age       -0.324193   -0.298712   -0.306227      -0.124439
# total_rooms               0.930874    0.854081    0.919410       0.204539
# total_bedrooms            1.000000    0.874220    0.979541      -0.003218
# population                0.874220    1.000000    0.904420       0.010679
# households                0.979541    0.904420    1.000000       0.017472
# median_income            -0.003218    0.010679    0.017472       1.000000
# median_house_value        0.053165   -0.019547    0.068076       0.689019
#
#                     median_house_value
# longitude                    -0.045866
# latitude                     -0.144787
# housing_median_age            0.099531
# total_rooms                   0.139026
# total_bedrooms                0.053165
# population                   -0.019547
# households                    0.068076
# median_income                 0.689019
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(train_data.corr(),annot=True,cmap='YlGnBu')
# Out:
# <ipython-input-17-b727c2f9702f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(),annot=True,cmap='YlGnBu')
# <Axes: >

# %%
#PREPROCESSING STAGE

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#assumption is that ocean proximity will influence the price 
#so the values placed for ocean proximity should be changed to numerical values. a more binary value
train_data.ocean_proximity.value_counts()# just for checking 
pd.get_dummies(train_data.ocean_proximity)#just for checking
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7302     -118.19     33.99                40.0     7.344719        6.075346
# 22       -122.27     37.84                52.0     7.798523        6.295266
# 17386    -120.44     34.97                22.0     7.390181        5.888878
# 3397     -118.31     34.26                41.0     7.168580        5.793014
# 564      -122.24     37.75                27.0     8.306966        6.625392
# ...          ...       ...                 ...          ...             ...
# 33       -122.27     37.83                49.0     7.412160        5.905362
# 15297    -117.35     33.16                22.0     7.194437        5.723585
# 18021    -121.96     37.24                26.0     8.017308        6.406880
# 15711    -122.44     37.79                52.0     7.642044        6.198479
# 11196    -117.93     33.84                34.0     7.678326        5.700444
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 7302     7.565793    6.059123         3.3869            157300.0          1
# 22       6.923629    6.171701         1.7250            113900.0          0
# 17386    7.319865    5.953243         1.7941            110300.0          1
# 3397     6.598509    5.755742         3.0583            160300.0          1
# 564      7.313220    6.682109         4.8711            286600.0          0
# ...           ...         ...            ...                 ...        ...
# 33       6.626718    5.799093         1.3750            104900.0          0
# 15297    6.364751    5.267858         3.9750            500001.0          0
# 18021    7.097549    6.333280         5.4683            430900.0          1
# 15711    7.110696    6.182085         4.0882            468800.0          0
# 11196    6.748760    5.723585         6.0531            287100.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 7302        0       0         0           0
# 22          0       0         1           0
# 17386       0       0         0           0
# 3397        0       0         0           0
# 564         0       0         1           0
# ...       ...     ...       ...         ...
# 33          0       0         1           0
# 15297       0       0         0           1
# 18021       0       0         0           0
# 15711       0       0         1           0
# 11196       0       0         0           0
#
# [16346 rows x 14 columns]

# %%
#this correlation matrix will show the correlation of pricing and the distance from the coast
plt.figure (figsize=(15,10))
sns.heatmap(train_data.corr(),annot=True,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
#use scatter plot to show the change of prices as they move further of the coast
#houses nearer the ocean are of the hue palrttr of red showing that their more expensive.
plt.figure (figsize=(15,10))
sns.scatterplot(x='latitude',y='longitude',data=train_data,hue = 'median_house_value',palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
#Feature engineering
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_bedrooms']
train_data['household_rooms']=train_data['total_rooms']/train_data['households']
plt.figure(figsize=(15,10))
sns.heatmap(train_data.corr(),annot=True,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
#training multiple models using linear regression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
x_train_s=scaler.fit_transform(x_train)

reg=LinearRegression()
reg.fit(x_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data=x_test.join(y_test)
test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)
test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)
test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_bedrooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']
x_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4701     -118.34     34.07                52.0     8.063378        6.964136
# 8629     -118.39     33.88                35.0     7.145196        5.379897
# 12163    -117.16     33.76                11.0     8.504108        6.835185
# 3754     -118.37     34.18                36.0     7.383368        5.924256
# 2840     -118.97     35.40                34.0     7.528332        5.780744
# ...          ...       ...                 ...          ...             ...
# 18651    -121.97     36.97                24.0     8.206856        6.769642
# 14412    -117.23     32.78                35.0     7.408531        5.874931
# 8043     -118.16     33.84                36.0     7.948738        6.352629
# 2599     -123.72     41.09                19.0     7.586296        6.068426
# 535      -122.27     37.78                13.0     7.611348        6.284134
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 4701     7.374629    6.905753         3.1766            225000.0          1
# 8629     6.257668    5.257495         6.0441            470000.0          1
# 12163    7.827640    6.734592         2.6250            155400.0          0
# 3754     7.104965    5.926926         2.9728            190200.0          1
# 2840     6.751101    5.736572         3.1906             76200.0          0
# ...           ...         ...            ...                 ...        ...
# 18651    7.578145    6.726233         2.8036            228500.0          0
# 14412    6.616065    5.888878         4.6293            356500.0          0
# 8043     7.288244    6.345636         3.8646            214600.0          1
# 2599     7.062192    5.897154         1.8208             50000.0          1
# 535      6.866933    6.188264         5.2601            292700.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 4701        0       0         0           0            1.0         1.167632
# 8629        0       0         0           0            1.0         1.359049
# 12163       1       0         0           0            1.0         1.262750
# 3754        0       0         0           0            1.0         1.245733
# 2840        1       0         0           0            1.0         1.312340
# ...       ...     ...       ...         ...            ...              ...
# 18651       0       0         0           1            1.0         1.220127
# 14412       0       0         0           1            1.0         1.258055
# 8043        0       0         0           0            1.0         1.252631
# 2599        0       0         0           0            1.0         1.286434
# 535         0       0         1           0            1.0         1.229965
#
# [4087 rows x 16 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7302     -118.19     33.99                40.0     7.344719        6.075346
# 22       -122.27     37.84                52.0     7.798523        6.295266
# 17386    -120.44     34.97                22.0     7.390181        5.888878
# 3397     -118.31     34.26                41.0     7.168580        5.793014
# 564      -122.24     37.75                27.0     8.306966        6.625392
# ...          ...       ...                 ...          ...             ...
# 33       -122.27     37.83                49.0     7.412160        5.905362
# 15297    -117.35     33.16                22.0     7.194437        5.723585
# 18021    -121.96     37.24                26.0     8.017308        6.406880
# 15711    -122.44     37.79                52.0     7.642044        6.198479
# 11196    -117.93     33.84                34.0     7.678326        5.700444
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 7302     7.565793    6.059123         3.3869            157300.0          1
# 22       6.923629    6.171701         1.7250            113900.0          0
# 17386    7.319865    5.953243         1.7941            110300.0          1
# 3397     6.598509    5.755742         3.0583            160300.0          1
# 564      7.313220    6.682109         4.8711            286600.0          0
# ...           ...         ...            ...                 ...        ...
# 33       6.626718    5.799093         1.3750            104900.0          0
# 15297    6.364751    5.267858         3.9750            500001.0          0
# 18021    7.097549    6.333280         5.4683            430900.0          1
# 15711    7.110696    6.182085         4.0882            468800.0          0
# 11196    6.748760    5.723585         6.0531            287100.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 7302        0       0         0           0            1.0         1.212175
# 22          0       0         1           0            1.0         1.263594
# 17386       0       0         0           0            1.0         1.241371
# 3397        0       0         0           0            1.0         1.245466
# 564         0       0         1           0            1.0         1.243165
# ...       ...     ...       ...         ...            ...              ...
# 33          0       0         1           0            1.0         1.278159
# 15297       0       0         0           1            1.0         1.365723
# 18021       0       0         0           0            1.0         1.265901
# 15711       0       0         1           0            1.0         1.236160
# 11196       0       0         0           0            1.0         1.341524
#
# [16346 rows x 16 columns]

# %%
x_test_s=scaler.transform(x_test)

# %%
reg.score(x_test_s,y_test)
# Out:
# 0.6802919468175892

# %%
from sklearn.ensemble import RandomForestRegressor
Rfm=RandomForestRegressor()
Rfm.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
Rfm.score(x_test,y_test)
# Out:
# 0.8219096536713784

# %%
y_pred=Rfm.predict(x_test)

# %%
y_pred
# Out:
# array([320101.06, 351719.07, 122611.  , ..., 220860.  ,  71683.  ,
#        283030.04])
